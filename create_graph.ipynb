# %%
page_rank={'ABE': 0.0007448596076398475,
 'ABI': 0.0007684393263194028,
 'ABQ': 0.0033268570935595597,
 'ABR': 0.0005442712286146716,
 'ABY': 0.0005892649750143869,
 'ACK': 0.0005275953630634876,
 'ACT': 0.0007232960808924366,
 'ACV': 0.0007238093603187743,
 'ACY': 0.0011416967171778859,
 'ADK': 0.0004995954717315861,
 'ADQ': 0.0005671093965612179,
 'AEX': 0.0008722328022165366,
 'AGS': 0.0007585757851773051,
 'AKN': 0.0004965266569666028,
 'ALB': 0.0015256715827140965,
 'ALO': 0.0005610345869410965,
 'AMA': 0.0009558616052261352,
 'ANC': 0.006954590901339735,
 'APN': 0.0005239120585863383,
 'ASE': 0.0010878636747893085,
 'ATL': 0.05132834493368593,
 'ATW': 0.0007798226070171969,
 'AUS': 0.006739813285839357,
 'AVL': 0.0008146663690969606,
 'AVP': 0.000669848132388766,
 'AZO': 0.0006936006727141934,
 'BDL': 0.003308141479318218,
 'BET': 0.0007727199858150965,
 'BFL': 0.0007923041528319821,
 'BGM': 0.0004993739391766617,
 'BGR': 0.0005174354730194704,
 'BHM': 0.0020827519555198766,
 'BIL': 0.0008476918651207842,
 'BIS': 0.0009627561237028273,
 'BJI': 0.0005088808552729357,
 'BLI': 0.00052743388545161,
 'BMI': 0.0009063578348133805,
 'BNA': 0.0069812345177751745,
 'BOI': 0.0024628223611380643,
 'BOS': 0.016815220280929556,
 'BPT': 0.0006266613211503372,
 'BQK': 0.0005762366258574162,
 'BQN': 0.0007307441997821836,
 'BRD': 0.0005278942051733162,
 'BRO': 0.0007253094530099572,
 'BRW': 0.0011758768530232494,
 'BTM': 0.0004936047971303384,
 'BTR': 0.0014380158594186235,
 'BTV': 0.000957208847148466,
 'BUF': 0.002861669662727727,
 'BUR': 0.0029479424287724323,
 'BWI': 0.013695911012110911,
 'BZN': 0.0009848489734263636,
 'CAE': 0.0011758815694204103,
 'CAK': 0.0013267868524762954,
 'CDC': 0.0005080432667933939,
 'CDV': 0.0012145833478743628,
 'CEC': 0.000499450346580875,
 'CHA': 0.0010305741937417857,
 'CHO': 0.000798627932519056,
 'CHS': 0.0018396818266544122,
 'CID': 0.0015072750844545158,
 'CIU': 0.0005394528675458002,
 'CLD': 0.0005267383019031295,
 'CLE': 0.005354481327344269,
 'CLL': 0.0007008740734618771,
 'CLT': 0.010537650155646979,
 'CMH': 0.003790290071256054,
 'CMI': 0.000763028430546948,
 'CMX': 0.0005528749231447257,
 'CNY': 0.0004713917668794839,
 'COD': 0.0005464477990326029,
 'COS': 0.001620805121254535,
 'COU': 0.0007254182238582678,
 'CPR': 0.0006394785973788008,
 'CRP': 0.0010712816312176648,
 'CRW': 0.0007638683083841072,
 'CSG': 0.0006036647293457755,
 'CVG': 0.0031206183526262506,
 'CWA': 0.0006663033215154008,
 'DAB': 0.000627010210149327,
 'DAL': 0.009043181500860935,
 'DAY': 0.0016380883942816913,
 'DBQ': 0.0005929932701435488,
 'DCA': 0.00954884473828339,
 'DEN': 0.039443222218029816,
 'DFW': 0.04433237157496868,
 'ROA': 0.0007270499658343638,
 'ROC': 0.0015321683435248247,
 'ROW': 0.0005913931606605199,
 'RST': 0.0007731251033058591,
 'RSW': 0.00425716502789868,
 'SAF': 0.000669205058026566,
 'SAN': 0.010713990083401206,
 'SAT': 0.004901988299915635,
 'SAV': 0.0013621227192079836,
 'SBA': 0.0012563676879366614,
 'SBN': 0.0011199227219854694,
 'SBP': 0.0008178812232251193,
 'SCC': 0.0008789697673232241,
 'SCE': 0.0005939022015751836,
 'SDF': 0.0017220602699302846,
 'SEA': 0.0175009117464829,
 'SFO': 0.031176938199023486,
 'SGF': 0.0013744873497043074,
 'SGU': 0.0006437971181425823,
 'SHV': 0.0013035718713219693,
 'SIT': 0.001141499272850621,
 'SJC': 0.005963175404901328,
 'SJT': 0.000650643670283413,
 'SJU': 0.0042711692268069265,
 'SLC': 0.016041354078172945,
 'SMF': 0.0063880263726769256,
 'SMX': 0.0005676294798422827,
 'SNA': 0.005208248492532902,
 'SPI': 0.0007003806254803154,
 'SPS': 0.0006323042268287079,
 'SRQ': 0.0008878006905993955,
 'STC': 0.0004862376688076973,
 'STL': 0.007048678316001596,
 'STT': 0.0010260877527411578,
 'STX': 0.0006077079393235926,
 'SUN': 0.0005682877074159381,
 'SUX': 0.0005589946709920038,
 'SWF': 0.0005728924922534903,
 'SYR': 0.0012799395623232998,
 'TLH': 0.0008667608986168488,
 'TOL': 0.00057123416668656,
 'TPA': 0.00962293859697933,
 'TRI': 0.000656463828560867,
 'TTN': 0.0013834076859463914,
 'TUL': 0.0025451333733865107,
 'TUS': 0.002696257984143093,
 'TVC': 0.0007965703903333744,
 'TWF': 0.0005091539183059368,
 'TXK': 0.0005709376275764258,
 'TYR': 0.0007472270712695781,
 'TYS': 0.001501476493463171,
 'UST': 0.0005468719505956317,
 'VEL': 0.0004691704638543984,
 'VLD': 0.0005858364620783419,
 'VPS': 0.0010660758806602937,
 'WRG': 0.0012315559338676439,
 'WYS': 0.00047361306990456934,
 'XNA': 0.0018796975591820666,
 'YAK': 0.0011162466821179394,
 'YUM': 0.0005833117102625314}

# %%
import pandas as pd

# %%
pgrk=pd.Series(page_rank)

# %%
airport=pd.read_csv('/Users/thebobs/Downloads/airport_network.csv')

# %%
pgrk*10000
# Out:
# ABE     7.448596
# ABI     7.684393
# ABQ    33.268571
# ABR     5.442712
# ABY     5.892650
#          ...
# WRG    12.315559
# WYS     4.736131
# XNA    18.796976
# YAK    11.162467
# YUM     5.833117
# Length: 322, dtype: float64

# %%
airport
# Out:
#      ORIGIN     origin_type       dest_type DEST  YEAR  delay_count
# 0       AZO  medium_airport   large_airport  ORD  2015          149
# 1       BOS   large_airport  medium_airport  CAK  2015           94
# 2       CLT   large_airport   large_airport  ORD  2015          834
# 3       CMH   large_airport   large_airport  MIA  2015          140
# 4       DAL   large_airport   large_airport  MKE  2015           59
# ...     ...             ...             ...  ...   ...          ...
# 4639    PVD   large_airport   large_airport  MCO  2015          333
# 4640    SAT   large_airport   large_airport  TPA  2015           86
# 4641    SLC   large_airport  medium_airport  CDC  2015           38
# 4642    MSY   large_airport   large_airport  SAT  2015           32
# 4643    SEA   large_airport   large_airport  CVG  2015           16
#
# [4644 rows x 6 columns]

# %%
nodes=pd.concat([airport[['ORIGIN','dest_type']].set_axis(['ID','type'],axis=1),airport[['DEST','dest_type']].set_axis(['ID','type'],axis=1)]).drop_duplicates('ID').reset_index(drop=True)

# %%
nodes['pagerank']=pgrk

# %%
nodes['pagerank']=(nodes['pagerank']*10000).round()

# %%
nodes=nodes.set_index("ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 nodes=nodes.set_index("ID")
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/tf/lib/python3.9/site-packages/pandas/core/frame.py:6009, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6006                 missing.append(col)
#    6008 if missing:
# -> 6009     raise KeyError(f"None of {missing} are in the columns")
# ...

# %%
nodes.index.name='id'

# %%
links=airport[['ORIGIN','DEST','delay_count']].set_axis(['source','target','value'],axis=1)

# %%
nodes_json=nodes.to_json(orient='records')

# %%
nodes_json
# Out:
# '[{"id":"AZO","type":"large_airport","pagerank":7.0,"index":0},{"id":"BOS","type":"medium_airport","pagerank":168.0,"index":1},{"id":"CLT","type":"large_airport","pagerank":105.0,"index":2},{"id":"CMH","type":"large_airport","pagerank":38.0,"index":3},{"id":"DAL","type":"large_airport","pagerank":90.0,"index":4},{"id":"DCA","type":"large_airport","pagerank":95.0,"index":5},{"id":"DFW","type":"medium_airport","pagerank":443.0,"index":6},{"id":"EWR","type":"medium_airport","pagerank":183.0,"index":7},{"id":"HSV","type":"large_airport","pagerank":10.0,"index":8},{"id":"IAH","type":"medium_airport","pagerank":236.0,"index":9},{"id":"JFK","type":"large_airport","pagerank":170.0,"index":10},{"id":"LNK","type":"large_airport","pagerank":8.0,"index":11},{"id":"MCI","type":"large_airport","pagerank":59.0,"index":12},{"id":"MFR","type":"large_airport","pagerank":9.0,"index":13},{"id":"MSY","type":"large_airport","pagerank":56.0,"index":14},{"id":"ORD","type":"large_airport","pagerank":563.0,"i
# ...

# %%
nodes['index']=nodes.index

# %%
nodes
# Out:
#       id            type  pagerank  index
# 0    AZO   large_airport       7.0      0
# 1    BOS  medium_airport     168.0      1
# 2    CLT   large_airport     105.0      2
# 3    CMH   large_airport      38.0      3
# 4    DAL   large_airport      90.0      4
# ..   ...             ...       ...    ...
# 317  CNY   large_airport       5.0    317
# 318  BQN  medium_airport       7.0    318
# 319  PSE  medium_airport       6.0    319
# 320  GUM   large_airport       6.0    320
# 321  ADK  medium_airport       5.0    321
#
# [322 rows x 4 columns]

# %%
nodes_index=nodes.set_index('id')['index'].to_dict()

# %%
nodes_index
# Out:
# {'AZO': 0,
#  'BOS': 1,
#  'CLT': 2,
#  'CMH': 3,
#  'DAL': 4,
#  'DCA': 5,
#  'DFW': 6,
#  'EWR': 7,
#  'HSV': 8,
#  'IAH': 9,
#  'JFK': 10,
#  'LNK': 11,
#  'MCI': 12,
#  'MFR': 13,
#  'MSY': 14,
#  'ORD': 15,
#  'PHX': 16,
#  'PIT': 17,
#  'PSP': 18,
#  'RST': 19,
#  'RSW': 20,
#  'SEA': 21,
#  'SFO': 22,
#  'TTN': 23,
#  'GSO': 24,
#  'STT': 25,
#  'DEN': 26,
#  'RIC': 27,
#  'ATL': 28,
#  'CID': 29,
#  'GEG': 30,
#  'LIH': 31,
#  'LSE': 32,
#  'MDW': 33,
#  'PHL': 34,
#  'SGF': 35,
#  'SHV': 36,
#  'XNA': 37,
#  'ALB': 38,
#  'DTW': 39,
#  'IAD': 40,
#  'ANC': 41,
#  'BUF': 42,
#  'COS': 43,
#  'DAY': 44,
#  'ERI': 45,
#  'LAS': 46,
#  'MCO': 47,
#  'MSP': 48,
#  'OKC': 49,
#  'SMF': 50,
#  'SLC': 51,
#  'AVL': 52,
#  'BHM': 53,
#  'CHA': 54,
#  'HOU': 55,
#  'IMT': 56,
#  'IND': 57,
#  'LGA': 58,
#  'ONT': 59,
#  'SAN': 60,
#  'TLH': 61,
#  'FLL': 62,
#  'GRR': 63,
#  'IDA': 64,
#  'LAX': 65,
#  'SAT': 66,
#  'AUS': 67,
#  'BDL': 68,
#  'BIS': 69,
#  'CLE': 70,
#  'LIT': 71,
# ...

# %%
links['source']=links['source'].map(nodes_index)

# %%
links['target']=links['target'].map(nodes_index)

# %%
links
# Out:
#       source  target  value
# 0          0      15    149
# 1          1     173     94
# 2          2      15    834
# 3          3      82    140
# 4          4      73     59
# ...      ...     ...    ...
# 4639     134      47    333
# 4640      66      85     86
# 4641      51     274     38
# 4642      14      66     32
# 4643      21      86     16
#
# [4644 rows x 3 columns]

# %%
links_json=links.to_json(orient='records')

# %%
nodes_json
# Out:
# '[{"id":"ABE","type":"large_airport","pagerank":7.0},{"id":"ABI","type":"large_airport","pagerank":8.0},{"id":"ABQ","type":"large_airport","pagerank":33.0},{"id":"ABR","type":"large_airport","pagerank":5.0},{"id":"ABY","type":"large_airport","pagerank":6.0},{"id":"ACK","type":"large_airport","pagerank":5.0},{"id":"ACT","type":"large_airport","pagerank":7.0},{"id":"ACV","type":"large_airport","pagerank":7.0},{"id":"ACY","type":"large_airport","pagerank":11.0},{"id":"ADK","type":"medium_airport","pagerank":5.0},{"id":"ADQ","type":"large_airport","pagerank":6.0},{"id":"AEX","type":"large_airport","pagerank":9.0},{"id":"AGS","type":"large_airport","pagerank":8.0},{"id":"AKN","type":"large_airport","pagerank":5.0},{"id":"ALB","type":"large_airport","pagerank":15.0},{"id":"ALO","type":"large_airport","pagerank":6.0},{"id":"AMA","type":"large_airport","pagerank":10.0},{"id":"ANC","type":"medium_airport","pagerank":70.0},{"id":"APN","type":"large_airport","pagerank":5.0},{"id":"ASE","type":"
# ...

# %%
nodes.loc['DFW']
# Out:
# type        medium_airport
# pagerank              0.99
# Name: DFW, dtype: object

# %%
graph={"nodes":nodes_json,"links":links_json}

# %%
import json

# %%
graph=json.dumps(graph,indent=2)

# %%
print(graph)
# Out:
# {
# ...

# %%
with open("/Users/thebobs/Downloads/nodes.json", 'w') as json_file:
    json_file.write(nodes_json)

# %%
with open("/Users/thebobs/Downloads/links.json", 'w') as json_file:
    json_file.write(links_json)

# %%
pgrk.to_csv("/Users/thebobs/Downloads/pagerank.csv")
